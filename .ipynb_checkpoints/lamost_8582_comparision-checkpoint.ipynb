# %% [markdown]
# # 综述
# ** 比较8582星表与苑老师给的星表cross部分有效温度差别 **
#
# _由于有一些星表中包含缺省项，我们需要使用pandas中使用dataframe读取csv中自动将缺省项补上的优势，来优化我们的自动化程式_
#
# _(fits的文件我们可以使用topcat改变格式并且给星表瘦身，以加快程序读取速度）_
#
# 我们需要实现的功能包含以下几点：
#
# 输入：
# * csv星表**_的名字_**
# * 两个星表三个温度
#
# 输出：
# * 星-温度 图

# %% [markdown]
# # 数据的引入和format (Alternative)

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import time
import datetime
from scipy.optimize import curve_fit
# %matplotlib inline

data_dir = '/Users/SY/Desktop/obic/data/'

# %%
save = data_dir + 'pictures/'

i = datetime.datetime.now()
date_now = "%s_%s_%s_" % (i.year, i.month, i.day) 

savename1 = save + date_now  + 'teff_tlusty'+'.png'
savename2 = save + date_now  + 'teff_val'+'.png'
savename3 = save + date_now  + 'logg_tlusty'+'.png'
savename4 = save + date_now  + 'lamost_teff_error'+'.png'

# %%
starcatalog_fram = pd.read_csv(data_dir + 'lamost_8582_2mass.csv')

starcatalog_fram_fil = starcatalog_fram.fillna(0)

print(starcatalog_fram.columns)
# Out:
# Index(['TEFF', 'ERR_TEFF', 'RA_1', 'DEC_1', 'LOGG', 'ERR_LOGG', 'FEH',
#        'ERR_FEH', 'SFD_ebv', 'ra_2', 'dec_2', 'teff_val', 'Teff_tlusty',
#        'logg_tlusty', '2MASS', 'RAJ2000', 'DEJ2000', 'errHalfMaj',
#        'errHalfMin', 'errPosAng', 'Jmag', 'Hmag', 'Kmag', 'e_Jmag', 'e_Hmag',
#        'e_Kmag', 'Qfl', 'Rfl', 'X', 'MeasureJD', 'angDist'],
#       dtype='object')

# %% [markdown]
# # 筛选数据

# %%
### variables

teff = 'TEFF'

color1 = 'Hmag'
color2 = 'Kmag'
err_teff = 'ERR_TEFF'

err_c1 = 'e_' + color1
#'e_' + color1
#color1 + 'err' 
#color1 + 'err'
#ERR_' + color1
#'e_' + color1

err_c2 = 'e_' + color2 
#'ERR_' + color2
#'e_' + color2

# %%
### get the good stars

# judge  data
starcatalog_fram_fil=starcatalog_fram_fil[((starcatalog_fram_fil[err_c1] != 0) \
                                          & (starcatalog_fram_fil[err_c2] != 0)\
                                          & (starcatalog_fram_fil[err_c1] != -99) \
                                          & (starcatalog_fram_fil[err_c2] != -99))\
                                         & ((starcatalog_fram_fil[color1] != 0)\
                                           & (starcatalog_fram_fil[color2] != 0)\
                                           & (starcatalog_fram_fil[color1] != -99) \
                                           & (starcatalog_fram_fil[color2] != -99))\
                                         &((starcatalog_fram_fil[err_c1] <=0.03))
                                          & ((starcatalog_fram_fil[err_c2] <=0.03))]

starcatalog_fram_fil=starcatalog_fram_fil[((starcatalog_fram_fil['Jmag'] >= 5.5) \
                                           &(starcatalog_fram_fil['Hmag'] >= 5)\
                                           &(starcatalog_fram_fil['Kmag'] >= 4.5))]\

#                                            &(starcatalog_fram_fil['W1mag'] >= 8.1) \
#                                            &(starcatalog_fram_fil['W2mag'] >= 6.7)\
#                                            &(starcatalog_fram_fil['W3mag'] >= 3.8))]
# ### additional judgement

# starcatalog_fram_fil=starcatalog_fram_fil[(starcatalog_fram_fil[err_c1] <=0.2)\
#                                            &(starcatalog_fram_fil[err_c2] <=0.05)]

# print(starcatalog_fram_fil.iloc[:,0].size)

# %% [markdown]
# # 读入Teff logg color

# %%
teff_1 = starcatalog_fram_fil['TEFF'].values
teff_2 = starcatalog_fram_fil['teff_val'].values
teff_3 = starcatalog_fram_fil['Teff_tlusty'].values

logg_1 =starcatalog_fram_fil['LOGG'].values 
logg_2 =starcatalog_fram_fil['logg_tlusty'].values 

#starcatalog_fram_fil

# %%
cr = starcatalog_fram_fil[color1].values-starcatalog_fram_fil[color2].values

# %% [markdown]
# ## 挑出异常的源

# %%
sz = teff_1.shape
teff1_err=[]
teff3_err=[]
cr_err=[]


for i in range(sz[0]):
    if (((int(teff_1[i]) >11600) & (int(teff_1[i]) <12000))\
       |((int(teff_1[i]) >12300) & (int(teff_1[i]) <13200))):
        
        teff1_err.append(teff_1[i])
        teff3_err.append(teff_3[i])
        cr_err.append(cr[[i]])
teff1_err=np.array(teff1_err)
teff3_err=np.array(teff3_err)

# %%
z1 = np.polyfit(teff_1, teff_3, 1)  #一次多项式拟合，相当于线性拟合
p1 = np.poly1d(z1)
print(z1,p1)



teffmax=np.max([np.max(teff_1),np.max(teff_3)])


x=np.linspace(0,teffmax,10000)
y1=z1[0]*x+z1[1]
y2=x


plt.figure(1,figsize=(9, 6))
plt.xlabel('$T_\mathrm{eff}(K)$')
plt.ylabel('$T_\mathrm{eff}(tlusty)(K)$')

plt.scatter(teff_1,teff_3,s=1,c='k',alpha=0.5)
plt.scatter(teff1_err,teff3_err,s=1,c='violet')
plt.plot(x,y2,'r',label='y=x')
plt.plot(x,y1,label='fitting curve')
plt.xlim(0,teffmax)
plt.ylim(0,teffmax)

plt.minorticks_on()
plt.legend(loc='lower right')
plt.savefig(savename1,dpi=200)
plt.show()
# Out:
# [  1.32247136e+00  -1.89257290e+03]
# 1.322 x - 1893

# %%
cc1='H'
cc2='Ks'


plt.figure(2,figsize=(9, 6))
ylabel = '$%s - %s$'%(cc1,cc2) 
plt.xlabel('$T_\mathrm{eff}(K)$')
plt.ylabel(ylabel)

plt.scatter(teff_1,cr,c='darkgrey',s=3,label='lamost')
plt.scatter(teff1_err,cr_err,s=3,c='blue',alpha=0.5,label='lamost_teff')
plt.scatter(teff3_err,cr_err,s=3,c='violet',alpha=0.5,label='8582_teff')

#plt.xlim(10000,30000)
#plt.ylim(0,teffmax)

plt.minorticks_on()
plt.legend(loc='upper right')
plt.savefig(savename4,dpi=200)
plt.show()

# %%
z1 = np.polyfit(teff_1, teff_2, 1)  #一次多项式拟合，相当于线性拟合
p1 = np.poly1d(z1)
print(z1,p1)



teffmax=np.max([np.max(teff_1),np.max(teff_2)])


x=np.linspace(0,teffmax,10000)
y1=z1[0]*x+z1[1]
y2=x


plt.figure(2,figsize=(15, 10))
plt.xlabel('$T_\mathrm{eff}(K)$')
plt.ylabel('$T_\mathrm{eff}(val)(K)$')
plt.scatter(teff_1,teff_2,s=1,c='k',alpha=0.5)
plt.plot(x,y2,'r',label='y=x')
plt.plot(x,y1,label='fitting curve')
plt.xlim(0,teffmax)
plt.ylim(0,teffmax)

plt.legend(loc='upper left')
plt.savefig(savename2,dpi=200)
plt.show()
# Out:
# [ -1.62287157e-01   9.12428264e+03]
# -0.1623 x + 9124

# %%
z1 = np.polyfit(logg_1, logg_2, 1)  #一次多项式拟合，相当于线性拟合
p1 = np.poly1d(z1)
print(z1,p1)



loggmax=np.max([np.max(logg_1),np.max(logg_2)])


x=np.linspace(0,loggmax,10000)
y1=z1[0]*x+z1[1]
y2=x


plt.figure(3,figsize=(15, 10))
plt.xlabel('$logg$')
plt.ylabel('$logg(tlusty)$')
plt.scatter(logg_1,logg_2,s=1,c='k',alpha=0.5)
plt.plot(x,y2,'r',label='y=x')
plt.plot(x,y1,label='fitting curve')
plt.xlim(2,loggmax)
plt.ylim(2,loggmax)

plt.legend(loc='lower right')
plt.savefig(savename3,dpi=200)
plt.show()
# Out:
# [-0.00946627  4.23050768]
# -0.009466 x + 4.231

# %%
x=np.linspace(1,np.max(teff))
print(x)
# Out:
# [  1.00000000e+00   2.00000000e+00   3.00000000e+00 ...,   9.99800000e+03
#    9.99900000e+03   1.00000000e+04]
