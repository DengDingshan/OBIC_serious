# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import time
import datetime
from scipy.optimize import curve_fit
# %matplotlib inline

data_dir = '/Users/SY/Desktop/obic/data/'
#data_dir = '/Users/dengdingshan/Documents/data/obic/'

# %%
starcatalog_fram = pd.read_csv(data_dir + 'lamost_obastar_new2.csv')

# %%
starcatalog_fram.columns
# Out:
# Index(['Unnamed: 0', 'TEFF', 'ERR_TEFF', 'RA', 'DEC', 'LOGG', 'ERR_LOGG',
#        'FEH', 'ERR_FEH'],
#       dtype='object')

# %%
plt.figure(1,figsize=(15, 10))  
plt.xlabel('$T_\mathrm{eff}(K)$',fontsize=14)
plt.ylabel('n',fontsize=14)
plt.hist(starcatalog_fram['TEFF'], bins= 10) 
plt.savefig(data_dir+'pictures/'+'lamost_amount_teff.png',dpi=200)
plt.show()
