# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import time
import datetime
from scipy.optimize import curve_fit
# %matplotlib inline

data_dir = '/Users/SY/Desktop/obic/data/'
#data_dir = '/Users/dengdingshan/Documents/data/obic/'

# %%
jh_a0 = 1.5
jh_a1 = -2.13*(10**(-4))
jh_a2 = -9.39*(10**(-9))
jh_a3 = 1.63*(10**(-12))

x1=np.linspace(3850,8350,20000)
y1=jh_a0+jh_a1*x1+jh_a2*(x1**2)+jh_a3*(x1**3)

x2=np.linspace(10000,24000,20000)
y2=np.exp(-x2)-0.0390555555578

# %%
plt.figure(1,figsize=(15, 10))
plt.plot(x1,y1)
plt.plot(x2,y2)

plt.show()
